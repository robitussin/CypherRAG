# %%
from generate_graph import get_propositions, generateEdges, createGraph, get_propositions_nosplit
from refine_graph import refine
from query_graph import QueryGraph
from tqdm import tqdm
tqdm.pandas()

# %%
# Open the file in read mode
raw_text = []
with open('datasets/sample.txt', 'r') as file:
    for x in file:
        raw_text.append(x)

# %%
raw_text
# Out:
# ['Barack Obama, born in Hawaii in 1961, served as the 44th President of the United States. In 1995, he published his memoir "Dreams from My Father". He gave a keynote speech at Acme Corp, a technology company founded in 2000 and headquartered in San Francisco. The event took place in 2010.\n']

# %%
propositions = []

for context in enumerate(tqdm(raw_text)):
    get_propositions_nosplit(context, propositions)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]c:\Users\SLY\.conda\envs\graphmaker\Lib\site-packages\langsmith\client.py:5301: LangChainBetaWarning: The function `loads` is in beta. It is actively being worked on, so the API may change.
#   prompt = loads(json.dumps(prompt_object.manifest))
# 100%|██████████| 1/1 [00:07<00:00,  7.56s/it]

# %%
# Open the file in read mode
with open('propositions.txt', 'r') as file:
    # Read all lines and store them in a list
    propositions_from_file = [line.strip() for line in file]

print(propositions_from_file)
# Out:
# ['Barack Obama was born in Hawaii in 1961.', 'Barack Obama served as the 44th President of the United States.', "Barack Obama published his memoir titled 'Dreams from My Father' in 1995.", 'Barack Obama gave a keynote speech at Acme Corp.', 'Acme Corp is a technology company.', 'Acme Corp was founded in 2000.', 'Acme Corp is headquartered in San Francisco.', 'The event where Barack Obama gave the keynote speech took place in 2010.']

# %%
list_of_edges = generateEdges(propositions_from_file)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
# ▶︎ GRAPH MAKER VERBOSE - 2025-09-01 21:30:08 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Person", "name": "Barack Obama", "properties": {"birth_date": "1961", "birth_place": "Hawaii", "occupation": ""}},
#         "node_2": {"label": "Place", "name": "Hawaii", "properties": {"country": "", "region": "", "coordinates": {}}},
#         "relationship": "Barack Obama was born in Hawaii.",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#  12%|█▎        | 1/8 [00:02<00:15,  2.18s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2025-09-01 21:30:10 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Person", "name": "Barack Obama", "properties": {"birth_date": "1961", "birth_place": "Hawaii", "occupation": "Politician"}},
#         "node_2": {"label": "Place", "name": "United States", "properties": {"country": "USA", "region": "North America", "coordinates": {}}},
#         "relationship": "Barack Obama served as the 44th President of the United States.",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#  25%|██▌       | 2/8 [00:04<00:13,  2.33s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2025-09-01 21:30:13 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Person", "name": "Barack Obama", "properties": {"birth_date": "", "birth_place": "", "occupation": ""}},
#         "node_2": {"label": "Object", "name": "Dreams from My Father", "properties": {"type": "book", "material": "paper", "function": "memoir"}},
#         "relationship": "Barack Obama published his memoir titled 'Dreams from My Father' in 1995.",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#  38%|███▊      | 3/8 [00:07<00:12,  2.43s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2025-09-01 21:30:15 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Person", "name": "Barack Obama", "properties": {"birth_date": {}, "birth_place": {}, "occupation": {}}},
#         "node_2": {"label": "Place", "name": "Acme Corp", "properties": {"country": {}, "region": {}, "coordinates": {}}},
#         "relationship": "Barack Obama gave a keynote speech at Acme Corp.",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#  50%|█████     | 4/8 [00:09<00:10,  2.51s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2025-09-01 21:30:18 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Object", "name": "Acme Corp", "properties": {"type": "company", "material": "", "function": "technology"}},
#         "node_2": {"label": "Miscellaneous", "name": "technology", "properties": {}},
#         "relationship": "Acme Corp is a technology company.",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#  62%|██████▎   | 5/8 [00:11<00:07,  2.36s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2025-09-01 21:30:20 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Object", "name": "Acme Corp", "properties": {"type": "Company", "material": "", "function": "Business"}},
#         "node_2": {"label": "Event", "name": "Founded", "properties": {"date": "2000", "location": "", "participants": ""}},
#         "relationship": "Acme Corp was founded in 2000.",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#  75%|███████▌  | 6/8 [00:14<00:04,  2.32s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2025-09-01 21:30:22 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Object", "name": "Acme Corp", "properties": {}},
#         "node_2": {"label": "Place", "name": "San Francisco", "properties": {"country": "USA", "region": "California", "coordinates": {}}},
#         "relationship": "Acme Corp is headquartered in San Francisco.",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#  88%|████████▊ | 7/8 [00:16<00:02,  2.21s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2025-09-01 21:30:24 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Person", "name": "Barack Obama", "properties": {"birth_date": "", "birth_place": "", "occupation": ""}},
#         "node_2": {"label": "Event", "name": "keynote speech", "properties": {"date": "2010", "location": "", "participants": "Barack Obama"}},
#         "relationship": "Barack Obama gave the keynote speech.",
#         "metadata": {},
#         "order": null
#     }
# ]
#
# 100%|██████████| 8/8 [00:18<00:00,  2.35s/it]

# %%
if createGraph(list_of_edges):
    print("Success")
else:
    print("Failed")
# Out:
# [Edge(node_1=Node(label='Person', name='Barack Obama', properties={'birth_date': '1961', 'birth_place': 'Hawaii', 'occupation': ''}), node_2=Node(label='Place', name='Hawaii', properties={'country': '', 'region': '', 'coordinates': {}}), relationship='Barack Obama was born in Hawaii.', metadata={'summary': 'Barack Obama was born in Hawaii in 1961.', 'generated_at': '2025-09-01 21:30:06.188227'}, order=0), Edge(node_1=Node(label='Person', name='Barack Obama', properties={'birth_date': '1961', 'birth_place': 'Hawaii', 'occupation': 'Politician'}), node_2=Node(label='Place', name='United States', properties={'country': 'USA', 'region': 'North America', 'coordinates': {}}), relationship='Barack Obama served as the 44th President of the United States.', metadata={'summary': 'Barack Obama served as the 44th President of the United States.', 'generated_at': '2025-09-01 21:30:06.188227'}, order=1), Edge(node_1=Node(label='Person', name='Barack Obama', properties={'birth_date': '', 'birth_place': '', 'occupation': ''}), node_2=Node(label='Object', name='Dreams from My Father', properties={'type': 'book', 'material': 'paper', 'function': 'memoir'}), relationship="Barack Obama published his memoir titled 'Dreams from My Father' in 1995.", metadata={'summary': "Barack Obama published his memoir titled 'Dreams from My Father' in 1995.", 'generated_at': '2025-09-01 21:30:06.188227'}, order=2), Edge(node_1=Node(label='Person', name='Barack Obama', properties={'birth_date': {}, 'birth_place': {}, 'occupation': {}}), node_2=Node(label='Place', name='Acme Corp', properties={'country': {}, 'region': {}, 'coordinates': {}}), relationship='Barack Obama gave a keynote speech at Acme Corp.', metadata={'summary': 'Barack Obama gave a keynote speech at Acme Corp.', 'generated_at': '2025-09-01 21:30:06.188227'}, order=3), Edge(node_1=Node(label='Object', name='Acme Corp', properties={'type': 'company', 'material': '', 'function': 'technology'}), node_2=Node(label='Miscellaneous', name='technology', properties={}), relationship='Acme Corp is a technology company.', metadata={'summary': 'Acme Corp is a technology company.', 'generated_at': '2025-09-01 21:30:06.188227'}, order=4), Edge(node_1=Node(label='Object', name='Acme Corp', properties={'type': 'Company', 'material': '', 'function': 'Business'}), node_2=Node(label='Event', name='Founded', properties={'date': '2000', 'location': '', 'participants': ''}), relationship='Acme Corp was founded in 2000.', metadata={'summary': 'Acme Corp was founded in 2000.', 'generated_at': '2025-09-01 21:30:06.188227'}, order=5), Edge(node_1=Node(label='Object', name='Acme Corp', properties={}), node_2=Node(label='Place', name='San Francisco', properties={'country': 'USA', 'region': 'California', 'coordinates': {}}), relationship='Acme Corp is headquartered in San Francisco.', metadata={'summary': 'Acme Corp is headquartered in San Francisco.', 'generated_at': '2025-09-01 21:30:06.188227'}, order=6), Edge(node_1=Node(label='Person', name='Barack Obama', properties={'birth_date': '', 'birth_place': '', 'occupation': ''}), node_2=Node(label='Event', name='keynote speech', properties={'date': '2010', 'location': '', 'participants': 'Barack Obama'}), relationship='Barack Obama gave the keynote speech.', metadata={'summary': 'The event where Barack Obama gave the keynote speech took place in 2010.', 'generated_at': '2025-09-01 21:30:06.188227'}, order=7)]
# Success
