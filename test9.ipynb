# %% [markdown]
# # Version 8.0
# - Entity to cluster comparison

# %%
import faiss
import numpy as np
from sklearn.preprocessing import normalize
from sklearn.feature_extraction.text import TfidfTransformer
from collections import defaultdict
from itertools import combinations
from sentence_transformers import SentenceTransformer, util
from fuzzywuzzy import fuzz
from knowledge_graph_maker import Edge, Node
from generate_graph import generateEdges, createGraph

# %%
class ClusterER:
    def __init__(self, pred2idx=None, sim_threshold=0.65, embedding_model="all-mpnet-base-v2"):
        """
        pred2idx: mapping predicate -> index for relational signatures
        sim_threshold: threshold to merge with existing cluster
        """
        self.model = SentenceTransformer(embedding_model)
        self.sim_threshold = sim_threshold

        # FAISS for cluster embeddings
        self.dim = 768  # mpnet embedding size
        self.faiss_index = faiss.IndexFlatIP(self.dim)
        self.int2cluster = {}  # mapping FAISS row -> cluster_id
        self.cluster_counter = 1

        # Clusters
        self.clusters = {}  # cluster_id -> cluster dict

        # Relational signature
        self.pred2idx = pred2idx or {}
        self.num_predicates = len(self.pred2idx)

    # ----------------------
    # Helper: String similarity
    # ----------------------
    def _string_sim(self, a, b):
        return fuzz.token_sort_ratio(a, b) / 100

    # ----------------------
    # Helper: Type compatibility
    # ----------------------
    # def _predict_type(self, entity_text, predicate=None):
    #     # Dummy placeholder: override with NER model if desired
    #     return "UNKNOWN"
    
    def _predict_type(self, entity_text, predicate=None):
        text = f"{entity_text} {predicate}" if predicate else entity_text

        try:
            entities = self.ner_pipeline(text)
        except Exception:
            return "UNKNOWN"

        for ent in entities:
            if ent["word"].lower() in entity_text.lower():
                label = ent["entity_group"]
                return {
                    "PER": "PERSON",
                    "ORG": "ORGANIZATION",
                    "LOC": "LOCATION",
                    "MISC": "MISC"
                }.get(label, "UNKNOWN")

        return "UNKNOWN"

    def _types_compatible(self, type1, type2):
        if type1 == "UNKNOWN" or type2 == "UNKNOWN":
            return True
        return type1 == type2

    # ----------------------
    # FAISS utilities
    # ----------------------
    def _add_to_faiss(self, cluster_id, emb):
        row = self.faiss_index.ntotal
        self.faiss_index.add(emb)
        self.int2cluster[row] = cluster_id

    def _semantic_blocking(self, entity_text, top_k=10):
        """Retrieve candidate clusters via FAISS"""
        if self.faiss_index.ntotal == 0:
            return []

        query_emb = self.model.encode(entity_text)
        query_emb = np.asarray(query_emb, dtype="float32").reshape(1, -1)
        faiss.normalize_L2(query_emb)

        scores, indices = self.faiss_index.search(query_emb, top_k)
        candidates = []
        for score, idx in zip(scores[0], indices[0]):
            if idx == -1 or score < self.sim_threshold:
                continue
            candidates.append(self.int2cluster[idx])
        return candidates

    # ----------------------
    # Relational signatures
    # ----------------------
    def _compute_candidate_relvec(self, predicate=None, other_entity_id=None):
        """Build candidate relational vector for current triple"""
        vec = np.zeros((1, self.num_predicates * 2), dtype=np.float32)
        if predicate in self.pred2idx:
            p_idx = self.pred2idx[predicate]
            vec[0, p_idx] += 1  # subject role
            if other_entity_id is not None:
                vec[0, p_idx + self.num_predicates] += 1  # object role
        return vec

    def _cluster_relational_similarity(self, cluster_id, candidate_vec=None):
        cluster_vec = self.clusters[cluster_id]["rel_signature"]
        if candidate_vec is None:
            candidate_vec = np.zeros_like(cluster_vec)

        # cosine similarity
        c_norm = cluster_vec / (np.linalg.norm(cluster_vec) + 1e-10)
        e_norm = candidate_vec / (np.linalg.norm(candidate_vec) + 1e-10)
        return float(np.dot(c_norm, e_norm.T))

    # ----------------------
    # Cluster management
    # ----------------------
    def _create_new_cluster(self, entity_text, predicate=None):
        cluster_id = f"C{self.cluster_counter}"
        self.cluster_counter += 1

        emb = self.model.encode(entity_text)
        emb = np.asarray(emb, dtype="float32").reshape(1, -1)
        faiss.normalize_L2(emb)

        rel_vec = self._compute_candidate_relvec(predicate)

        self.clusters[cluster_id] = {
            "members": {entity_text},
            "centroid": emb,
            "type": self._predict_type(entity_text, predicate),
            "neighbors": set(),
            "rel_signature": rel_vec
        }

        self._add_to_faiss(cluster_id, emb)
        return cluster_id, "INSERT"

    def _update_cluster(self, cluster_id, new_entity_text, predicate=None):
        cluster = self.clusters[cluster_id]

        new_emb = self.model.encode(new_entity_text)
        new_emb = np.asarray(new_emb, dtype="float32").reshape(1, -1)
        faiss.normalize_L2(new_emb)

        # Update centroid
        cluster["centroid"] = normalize(cluster["centroid"] + new_emb, norm="l2")
        cluster["members"].add(new_entity_text)

        # Update relational signature
        if predicate:
            candidate_vec = self._compute_candidate_relvec(predicate)
            cluster["rel_signature"] += candidate_vec

        # Rebuild FAISS for simplicity
        self._rebuild_faiss()

    def _rebuild_faiss(self):
        self.faiss_index.reset()
        self.int2cluster = {}
        for cid, c in self.clusters.items():
            self._add_to_faiss(cid, c["centroid"])

    # ----------------------
    # Cluster-level similarity
    # ----------------------
    def _cluster_similarity(self, entity_text, cluster_id, predicate=None, other_entity_id=None):
        cluster = self.clusters[cluster_id]

        # string similarity
        s_sim = max(self._string_sim(entity_text, m) for m in cluster["members"])

        # embedding similarity
        context = f"{entity_text} in relation {predicate}" if predicate else entity_text
        emb_query = self.model.encode(context)
        e_sim = util.cos_sim(emb_query, cluster["centroid"]).item()

        # type similarity
        new_type = self._predict_type(entity_text, predicate)
        p_sim = 1.0 if self._types_compatible(new_type, cluster["type"]) else 0.0

        # relational similarity
        candidate_relvec = self._compute_candidate_relvec(predicate, other_entity_id)
        r_sim = self._cluster_relational_similarity(cluster_id, candidate_relvec)

        # composite
        return 0.25 * s_sim + 0.40 * e_sim + 0.10 * p_sim + 0.25 * r_sim

    # ----------------------
    # Resolve entity
    # ----------------------
    def resolve_entity(self, entity_text, predicate=None, other_entity_id=None):
        candidates = self._semantic_blocking(entity_text)
        best_score = 0
        best_cluster = None

        for cluster_id in candidates:
            score = self._cluster_similarity(entity_text, cluster_id, predicate, other_entity_id)
            if score > best_score:
                best_score = score
                best_cluster = cluster_id

        if best_cluster and best_score >= self.sim_threshold:
            self._update_cluster(best_cluster, entity_text, predicate)
            return best_cluster, "MERGE"

        return self._create_new_cluster(entity_text, predicate)

    # ----------------------
    # Get entity -> cluster mapping
    # ----------------------
    def get_entity_mapping(self):
        mapping = {}
        for cid, cluster in self.clusters.items():
            for m in cluster["members"]:
                mapping[m] = cid
        return mapping

    # ----------------------
    # Evaluation functions
    # ----------------------
    @staticmethod
    def pairwise_links(items):
        if len(items) == 0:
            return set()
        if len(items) == 1:
            return {frozenset(items)}
        return set(frozenset([a, b]) for a, b in combinations(items, 2))

    @staticmethod
    def build_gold_entity_map(gold_clusters):
        gold_entity_map = defaultdict(set)
        for gold_cluster, entities in gold_clusters.items():
            for e in entities:
                gold_entity_map[e].add(gold_cluster)
        return gold_entity_map

    @staticmethod
    def evaluate_cluster_alignment(gold_clusters, predicted_clusters):
        gold_entity_map = ClusterER.build_gold_entity_map(gold_clusters)
        for pred_cluster_id, pred_entities in predicted_clusters.items():
            matched_gold = defaultdict(set)
            for e in pred_entities:
                golds = gold_entity_map.get(e, set())
                if not golds:
                    matched_gold["UNSEEN"].add(e)
                else:
                    for g in golds:
                        matched_gold[g].add(e)
            print("="*50)
            print(f"Predicted Cluster: {pred_cluster_id}")
            print(f"Entities: {pred_entities}")
            if len(matched_gold) == 1:
                print(f"Pure match with gold cluster: {next(iter(matched_gold))}")
            else:
                print("Mixed cluster matches:")
                for g, ents in matched_gold.items():
                    print(f"  - {g}: {ents}")

    def evaluate(self, toy_dataset):
        # build gold clusters
        gold_clusters = defaultdict(set)
        for t in toy_dataset:
            gold_clusters[t["subject_gold"]].add(t["subject"])
            gold_clusters[t["object_gold"]].add(t["object"])

        # predicted clusters
        pred_clusters = defaultdict(set)
        mapping = self.get_entity_mapping()
        for mention, cid in mapping.items():
            pred_clusters[cid].add(mention)

        # pairwise metrics
        gold_links = set()
        for entities in gold_clusters.values():
            gold_links.update(self.pairwise_links(entities))
        pred_links = set()
        for entities in pred_clusters.values():
            pred_links.update(self.pairwise_links(entities))

        tp = len(gold_links & pred_links)
        fp = len(pred_links - gold_links)
        fn = len(gold_links - pred_links)
        precision = tp / (tp + fp + 1e-10)
        recall = tp / (tp + fn + 1e-10)
        f1 = 2 * precision * recall / (precision + recall + 1e-10)

        print("\n=== Evaluation Results ===")
        print(f"Precision: {precision:.4f}")
        print(f"Recall   : {recall:.4f}")
        print(f"F1       : {f1:.4f}")

        print("\n=== Cluster Alignment ===")
        self.evaluate_cluster_alignment(gold_clusters, pred_clusters)
        return precision, recall, f1
    
    def deduplicate_edges(self, list_of_edges, merge_metadata=True):
        """
        Remove or merge duplicate edges after entity resolution.

        Returns:
            unique_edges: list of canonicalized edges
            duplicate_count: number of removed edges
        """

        canonical_edges = {}
        duplicate_count = 0

        for edge in list_of_edges:
            s_text = edge.node_1.name
            o_text = edge.node_2.name
            predicate = edge.relationship

            # Resolve to cluster IDs
            s_cluster = self.get_entity_mapping().get(s_text)
            o_cluster = self.get_entity_mapping().get(o_text)

            # If resolution failed, skip
            if s_cluster is None or o_cluster is None:
                continue

            # Canonical triple key
            key = (s_cluster, predicate, o_cluster)

            if key not in canonical_edges:
                canonical_edges[key] = {
                    "subject_cluster": s_cluster,
                    "predicate": predicate,
                    "object_cluster": o_cluster,
                    "mentions": [(s_text, o_text)],
                    "metadata": [edge.metadata]
                }
            else:
                duplicate_count += 1
                canonical_edges[key]["mentions"].append((s_text, o_text))

                if merge_metadata:
                    canonical_edges[key]["metadata"].append(edge.metadata)

        return list(canonical_edges.values()), duplicate_count
    
    def process_edges(self, list_of_edges):
        for edge in list_of_edges:

            subj = edge.node_1.name
            obj = edge.node_2.name
            pred = edge.relationship

            subj_cluster, _ = self.resolve_entity(subj, predicate=pred)
            obj_cluster, _ = self.resolve_entity(obj, predicate=pred,
                                                other_entity_id=subj_cluster)

        return self.deduplicate_edges_to_graph(list_of_edges)
    
    # def deduplicate_edges_to_graph(self, list_of_edges):
    #     """
    #     Deduplicate edges and return them in original Edge(Node, Node) format,
    #     but canonicalized using cluster IDs.
    #     """

    #     entity_map = self.get_entity_mapping()
    #     canonical_edges = {}
    #     new_order = 0

    #     for edge in list_of_edges:
    #         s_text = edge.node_1.name
    #         o_text = edge.node_2.name
    #         predicate = edge.relationship

    #         s_cluster = entity_map.get(s_text)
    #         o_cluster = entity_map.get(o_text)

    #         if s_cluster is None or o_cluster is None:
    #             continue

    #         key = (s_cluster, predicate, o_cluster)

    #         if key not in canonical_edges:
    #             canonical_edges[key] = {
    #                 "subject_cluster": s_cluster,
    #                 "object_cluster": o_cluster,
    #                 "predicate": predicate,
    #                 "subject_label": edge.node_1.label,
    #                 "object_label": edge.node_2.label,
    #                 "metadata": [edge.metadata],
    #                 "order": new_order
    #             }
    #             new_order += 1
    #         else:
    #             canonical_edges[key]["metadata"].append(edge.metadata)

    #     # Convert back to original Edge format
    #     deduplicated_edges = []

    #     for data in canonical_edges.values():

    #         # Choose canonical name (cluster ID as name)
    #         subject_node = Node(
    #             label=data["subject_label"],
    #             name=data["subject_cluster"],
    #             properties={}
    #         )

    #         object_node = Node(
    #             label=data["object_label"],
    #             name=data["object_cluster"],
    #             properties={}
    #         )

    #         # Merge metadata
    #         merged_metadata = {
    #             "merged_from": data["metadata"]
    #         }

    #         deduplicated_edges.append(
    #             Edge(
    #                 node_1=subject_node,
    #                 node_2=object_node,
    #                 relationship=data["predicate"],
    #                 metadata=merged_metadata,
    #                 order=data["order"]
    #             )
    #         )

    #     return deduplicated_edges
    
    
    def deduplicate_edges_to_graph(self, list_of_edges):
        """
        Deduplicate edges but reconstruct them using canonical mention names
        instead of cluster IDs.
        """

        entity_map = self.get_entity_mapping()

        # Step 1: Build cluster -> canonical mention name mapping
        cluster_to_name = {}
        cluster_to_label = {}

        for cluster_id, cluster_data in self.clusters.items():
            # Choose first inserted mention as canonical
            canonical_name = next(iter(cluster_data["members"]))
            cluster_to_name[cluster_id] = canonical_name

        canonical_edges = {}
        new_order = 0

        for edge in list_of_edges:
            s_text = edge.node_1.name
            o_text = edge.node_2.name
            predicate = edge.relationship

            s_cluster = entity_map.get(s_text)
            o_cluster = entity_map.get(o_text)

            if s_cluster is None or o_cluster is None:
                continue

            key = (s_cluster, predicate, o_cluster)

            if key not in canonical_edges:
                canonical_edges[key] = {
                    "subject_cluster": s_cluster,
                    "object_cluster": o_cluster,
                    "predicate": predicate,
                    "subject_label": edge.node_1.label,
                    "object_label": edge.node_2.label,
                    "metadata": [edge.metadata],
                    "order": new_order
                }
                new_order += 1
            else:
                canonical_edges[key]["metadata"].append(edge.metadata)

        # Step 2: Reconstruct graph using canonical mention names
        deduplicated_edges = []

        for data in canonical_edges.values():

            subject_node = Node(
                label=data["subject_label"],
                name=cluster_to_name[data["subject_cluster"]],
                properties={}
            )

            object_node = Node(
                label=data["object_label"],
                name=cluster_to_name[data["object_cluster"]],
                properties={}
            )

            merged_metadata = {
                "merged_from": data["metadata"]
            }

            deduplicated_edges.append(
                Edge(
                    node_1=subject_node,
                    node_2=object_node,
                    relationship=data["predicate"],
                    metadata=merged_metadata,
                    order=data["order"]
                )
            )

        return deduplicated_edges

# %% [markdown]
# ## Faculty Manual

# %%
# Open the file in read mode
with open('propositions_facultymanual.txt', 'r') as file:
    # Read all lines and store them in a list
    propositions_from_file = [line.strip() for line in file]

print(propositions_from_file)

props = propositions_from_file

list_of_edges = generateEdges(props)

# %%
# 1. Initialize predicate vocab for relational signatures
# pred2idx = {"works_at":0, "owns":1, "located_in":2}
pred2idx = {}

# 2. Initialize resolver
resolver = ClusterER(pred2idx=pred2idx, sim_threshold=0.65)

unique_edges = resolver.process_edges(list_of_edges)

# %% [markdown]
# Graph without ER

# %%
if createGraph(list_of_edges):
    print("Success")
else:
    print("Failed")

# %% [markdown]
# Graph with ER

# %%
# 1. Initialize predicate vocab for relational signatures
# pred2idx = {"works_at":0, "owns":1, "located_in":2}
pred2idx = {}

# 2. Initialize resolver
resolver = ClusterER(pred2idx=pred2idx, sim_threshold=0.65)

unique_edges = resolver.process_edges(list_of_edges)

# %%
if createGraph(unique_edges):
    print("Success")
else:
    print("Failed")

# %%
#20 Questions

faculty_manual_questions = [
    {
        "ID": 1,
        "Question": "What is the official title of this document and its reference number?",
        "Answer": "The official title of this document is \"FACULTY MANUAL\" and its reference number is \"OPR-HRD-D-M-003\"."
    },
    {
        "ID": 2,
        "Question": "When is the date of effectivity for this Faculty Manual and what previous version does it supersede?",
        "Answer": "The date of effectivity for this Faculty Manual is August 1, 2023, and it supersedes the version from December 1, 2019."
    },
    {
        "ID": 3,
        "Question": "What is the purpose of this Faculty Manual, according to the Foreword?",
        "Answer": "According to the Foreword, this Faculty Manual is prepared to provide an overview of National University's policies, rules, regulations, and benefits. It also aims to familiarize faculty with important information and provide employment guidelines to foster a safe and healthy work environment."
    },
    {
        "ID": 4,
        "Question": "What are the \"5 Commandments\" for data privacy compliance emphasized by the Commission on Higher Education (CHED) as mentioned in the Privacy Statement?",
        "Answer": "The \"5 Commandments\" for data privacy compliance emphasized by CHED are: appointing a Data Protection Officer (DPO); conducting a Privacy Impact Assessment; creating a Privacy Management Program; implementing privacy and data protection measures; and performing Breach Reporting Procedure."
    },
    {
        "ID": 5,
        "Question": "Who founded National University and when?",
        "Answer": "National University was founded by Don Mariano Fortunato Jhocson on August 1, 1900."
    },
    {
        "ID": 6,
        "Question": "What is the vision of National University?",
        "Answer": "The vision of National University is to be a dynamic private institution committed to nation-building, recognized internationally in education and research."
    },
    {
        "ID": 7,
        "Question": "What are the types of contracts applicable to employees as listed in Section 5.1 of Chapter 3?",
        "Answer": "The types of contracts applicable to employees include: Probationary Employment Contract (For Full-time Faculty Member), Employment Contract (For regularization), Contractual Full-Time Employment Agreement (Non-Regular faculty), Contractual Employment Contract (For Part-time Faculty Member), Adjunct Faculty Contract, Project-based Employment Contract (For Non-Teaching Personnel), and Consultancy Contract."
    },
    {
        "ID": 8,
        "Question": "What is the policy regarding solicitation and distribution of materials in the campus?",
        "Answer": "For the safety, convenience, and protection of all faculty, National University always prohibits solicitation and distribution of materials in the campus."
    },
    {
        "ID": 9,
        "Question": "What is the maximum score a faculty can achieve in Research and Innovation, and what are some categories for points allocation?",
        "Answer": "A faculty's maximum score in Research and Innovation is 30 points. Categories for points allocation include: Publication: Journal Articles, Publication: Conference Proceedings, Publication: Book Chapters and International Handbook and Encyclopedia, Externally Funded Research/Innovation/Resiliency Project, and Completed Internally Funded Research/Innovation/Resiliency Project."
    },
    {
        "ID": 10,
        "Question": "What is the \"No Work, No Pay\" policy specifically for Part-time Faculty regarding tardiness and absences?",
        "Answer": "There is a \"No Work, No Pay\" policy for Part-time Faculty, and tardiness and absences are computed based on their hourly rate."
    },
    {
        "ID": 11,
        "Question": "What is the current student enrollment for the upcoming academic year across all programs?",
        "Answer": ""
    },
    {
        "ID": 12,
        "Question": "What specific pedagogical approaches are recommended for teaching a master's level course in computer science?",
        "Answer": ""
    },
    {
        "ID": 13,
        "Question": "Who are the current deans of each college, and what are their academic backgrounds?",
        "Answer": ""
    },
    {
        "ID": 14,
        "Question": "What is the total budget allocated for faculty research grants in the next fiscal year?",
        "Answer": ""
    },
    {
        "ID": 15,
        "Question": "What are the technical specifications of the university's learning management system?",
        "Answer": ""
    },
    {
        "ID": 16,
        "Question": "What is the university's strategy for international partnerships in the next five years?",
        "Answer": ""
    },
    {
        "ID": 17,
        "Question": "How many faculty members are expected to retire in the next three years?",
        "Answer": ""
    },
    {
        "ID": 18,
        "Question": "What is the average student-to-faculty ratio in undergraduate programs?",
        "Answer": ""
    },
    {
        "ID": 19,
        "Question": "What are the detailed architectural plans for the new campus building under construction?",
        "Answer": ""
    },
    {
        "ID": 20,
        "Question": "What is the university's market share in tertiary education in the Philippines compared to other private institutions?",
        "Answer": ""
    }
]

# %%
from langchain_ollama import ChatOllama
from query_graph import QueryGraph

# model = "llama3.2:3b"
# model = "gemma3:12b-it-qat"

# ollama_llm = ChatOllama(
#     model = model,
#     temperature = 0.8,
#     num_predict = 256,
# )

qg = QueryGraph()

# %%
answers = []

for i in faculty_manual_questions:
    
    answerdict = {
        "ID": i['ID'],
        "Question": i['Question'],
        "GroundTruth": i['Answer'],
        "Prediction": ""
    }
    
    print(i['Question'])
    print(i['Answer'])
    question = i['Question']
    answer = i['Answer']

    req = qg.get_requirements(question)
    result = qg.answer_question(question, req.content)
    
    if result is not None:
        answerdict["Prediction"] = result['result']
        answers.append(answerdict)

# %%
answers

# %%
import re
import string

def normalize_answer(s):
    """Lower text and remove punctuation, articles and extra whitespace."""

    def remove_articles(text):
        return re.sub(r'\b(a|an|the)\b', ' ', text)

    def white_space_fix(text):
        return ' '.join(text.split())

    def remove_punctuation(text):
        return text.translate(str.maketrans('', '', string.punctuation))

    def lower(text):
        return text.lower()

    return white_space_fix(remove_articles(remove_punctuation(lower(s))))

def exact_match_score(prediction, ground_truth):
    return normalize_answer(prediction) == normalize_answer(ground_truth)

# %%
resultlist = []

for i in faculty_manual_questions:
    for j in answers:
        if i['ID'] == j['ID']:
            answerdict = {
                "Question": i['Question'],  
                "GroundTruth": i['Answer'],
                "Prediction": j['Prediction']
            }
    resultlist.append(answerdict)

# %%
resultlist

# %%
# Compute EM score per QA pair
em_scores = [exact_match_score(item["Prediction"], item["GroundTruth"]) for item in resultlist]

# Compute overall EM accuracy
em_accuracy = sum(em_scores) / len(em_scores)

print(f"Exact Match Accuracy: {em_accuracy:.2%}")

# %%
from rouge_score import rouge_scorer

# Initialize scorer
scorer = rouge_scorer.RougeScorer(['rougeL'], use_stemmer=True)

# Example answers
ground_truth = "The Faculty Services Office handles faculty ranking and promotion."
predicted = "Faculty ranking and promotion are managed by the Faculty Services Office."

# Compute ROUGE-L
scores = scorer.score(ground_truth, predicted)

print("ROUGE-L Precision:", scores['rougeL'].precision)
print("ROUGE-L Recall:", scores['rougeL'].recall)
print("ROUGE-L F1:", scores['rougeL'].fmeasure)

# %%
predictions = []
ground_truths = []

for i in resultlist:
    ground_truths.append(i['GroundTruth'])
    predictions.append(i['Prediction'])

# %%
predictions

# %%
ground_truths

# %% [markdown]
# rouge-l score for gpt4omini with ER

# %%
scorer = rouge_scorer.RougeScorer(['rougeL'], use_stemmer=True)

total_f1 = 0

for gt, pred in zip(ground_truths, predictions):
    score = scorer.score(gt, pred)
    total_f1 += score['rougeL'].fmeasure

average_f1 = total_f1 / len(ground_truths)

print("Average ROUGE-L F1:", average_f1)

# %% [markdown]
# ## Research Manual

# %%
# Open the file in read mode
with open('propositions_researchmanual.txt', 'r') as file:
    # Read all lines and store them in a list
    propositions_from_file = [line.strip() for line in file]

print(propositions_from_file)

props = propositions_from_file

list_of_edges = generateEdges(props)
# Out:
# ['The document is a manual version control log.', "The title of the document is 'Version Control'.", 'The log contains entries with a number, description, date, and remarks.', 'The first entry is RAD – RI – D – M – 001.', "The description of the first entry is 'Guidelines on the conduct of Research efforts within National University'.", 'The date of the first entry is November 1, 2020.', 'The remarks for the first entry state that it was approved on 2020.', 'The second entry is RAD – RS – D – M – 001.', "The description of the second entry is 'Guidelines on the conduct of Research efforts within National University'.", 'The date of the second entry is April 4, 2022.', 'The remarks for the second entry state that it was approved on 2022.', 'The manual approval and distribution list was prepared by Johanna G. Minglana.', 'Johanna G. Minglana holds the title of Quality Management Office Director.', 'The manual approval and distribution list was checked by Johanna G. Minglana.', 'The date of preparation is April 4, 2022.', 'The manual approval and distribution list was concurred by Renato Carlos H. Ermita, Jr.', 'Renato Carlos H. Ermita, Jr. holds the title of President.', 'The date of concurrence is April 4, 2022.', 'The manual approval and distribution list was approved by Renato Carlos H. Ermita, Jr.', 'The date of approval is April 4, 2022.', 'The distribution list includes the Quality Management Office.', 'The Quality Management Office received the original copy.', 'The distribution list includes the Office of the President.', 'The Office of the President received copy 1.', 'The distribution list includes the Office of the Vice-President for Research and Development.', 'The Office of the Vice-President for Research and Development received copy 2.', 'The distribution list includes the Center for Research.', 'The Center for Research received copy 3.', 'The distribution list includes the Center for Innovation and Entrepreneurship.', 'The Center for Innovation and Entrepreneurship received copy 4.', 'The distribution list includes the Center for Resilient Philippines.', 'The Center for Resilient Philippines received copy 5.', 'The distribution list includes all campuses.', 'All campuses received copy 6.', 'The document contains a table of contents.', 'The table of contents includes a Manual Version Control Log.', 'The table of contents includes a Manual Approval and Distribution List.', 'The table of contents includes a Foreword.', 'The table of contents includes a List of Abbreviations.', "The table of contents includes Chapter 1: Research and Development as Part of National University's Plan.", 'Chapter 1 includes A. Center for Research.', 'Chapter 1 includes B. Center for Innovation and Entrepreneurship.', 'Chapter 1 includes C. Center for Resilient Philippines.', 'The table of contents includes Chapter 2: National University Research Agenda.', 'Chapter 2 includes A. Research Goals.', 'Chapter 2 includes B. Research Themes.', 'Chapter 2 includes C. Research Disciplines.', 'The table of contents includes Chapter 3: College and Campus Research Agenda.', 'Chapter 3 includes A. College of Education, Arts and Sciences.', 'Chapter 3 includes B. College of Business and Accountancy.', 'Chapter 3 includes C. College of Architecture.', 'Chapter 3 includes D. College of Engineering.', 'Chapter 3 includes E. College of Computing and Information Technologies.', 'Chapter 3 includes F. College of Allied Health.', 'Chapter 3 includes G. College of Dentistry.', 'Chapter 3 includes H. College of Tourism and Hospitality Management.', 'Chapter 3 includes I. NU MOA.', 'Chapter 3 includes J. NU Philippines.', 'The table of contents includes Chapter 4: The University Research and Development Council.', 'The table of contents includes Chapter 5: Research As Defined By The College Faculty Ranking And Classification System.', 'The table of contents includes Chapter 6: Types of Research Projects.', 'Types of Research includes various categories.', 'Com ...
#   0%|          | 0/1453 [00:00<?, ?it/s]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:53:48 - INFO
# LLM Response:
# []
#
#   0%|          | 1/1453 [00:00<22:57,  1.05it/s]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:53:50 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Version Control", "properties": {}},
#         "node_2": {"label": "Object", "name": "Document", "properties": {}},
#         "relationship": "IS_TITLE_OF",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   0%|          | 2/1453 [00:03<42:35,  1.76s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:53:51 - INFO
# LLM Response:
# []
#
#   0%|          | 3/1453 [00:04<33:53,  1.40s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:53:53 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "RAD – RI – D – M – 001", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "First Entry", "properties": {}},
#         "relationship": "IS_A",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   0%|          | 4/1453 [00:06<43:37,  1.81s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:53:56 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Policy", "name": "Guidelines on the conduct of Research efforts", "properties": {"type": "Research Guidelines", "effective_date": "", "scope": "National University"}},
#         "node_2": {"label": "Organization", "name": "National University", "properties": {}},
#         "relationship": "APPLIES_TO",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   0%|          | 5/1453 [00:09<48:15,  2.00s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:53:56 - INFO
# LLM Response:
# []
#
#   0%|          | 6/1453 [00:09<36:47,  1.53s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:53:57 - INFO
# LLM Response:
# []
#
#   0%|          | 7/1453 [00:10<30:25,  1.26s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:53:58 - INFO
# LLM Response:
# []
#
#
#   1%|          | 8/1453 [00:10<25:11,  1.05s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:54:00 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Policy", "name": "Guidelines on the conduct of Research efforts", "properties": {"type": "Research Guidelines", "effective_date": "", "scope": "National University"}},
#         "node_2": {"label": "Organization", "name": "National University", "properties": {}},
#         "relationship": "GOVERNS",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   1%|          | 9/1453 [00:12<32:27,  1.35s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:54:00 - INFO
# LLM Response:
# []
#
#   1%|          | 10/1453 [00:13<27:12,  1.13s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:54:01 - INFO
# LLM Response:
# []
#
#   1%|          | 11/1453 [00:14<22:52,  1.05it/s]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:54:03 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Person", "name": "Johanna G. Minglana", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "manual approval and distribution list", "properties": {}},
#         "relationship": "PREPARED",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   1%|          | 12/1453 [00:16<31:58,  1.33s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:54:05 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Person", "name": "Johanna G. Minglana", "properties": {"occupation": "Quality Management Office Director"}},
#         "node_2": {"label": "Position", "name": "Quality Management Office Director", "properties": {"title": "Quality Management Office Director", "level": "Director", "responsibilities": {}}},
#         "relationship": "HOLDS_POSITION",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   1%|          | 13/1453 [00:18<37:21,  1.56s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:54:07 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Person", "name": "Johanna G. Minglana", "properties": {"occupation": "unknown", "birth_place": "unknown"}},
#         "node_2": {"label": "Miscellaneous", "name": "manual approval and distribution list", "properties": {}},
#         "relationship": "CHECKED_BY",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   1%|          | 14/1453 [00:20<40:16,  1.68s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:54:08 - INFO
# LLM Response:
# []
#
#   1%|          | 15/1453 [00:20<31:55,  1.33s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:54:10 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Person", "name": "Renato Carlos H. Ermita, Jr.", "properties": {"occupation": "unknown", "birth_place": "unknown"}},
#         "node_2": {"label": "Miscellaneous", "name": "manual approval and distribution list", "properties": {}},
#         "relationship": "CONCURRED_BY",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   1%|          | 16/1453 [00:22<36:28,  1.52s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:54:11 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Person", "name": "Renato Carlos H. Ermita, Jr.", "properties": {"rank": "President", "birth_place": "", "occupation": ""}},
#         "node_2": {"label": "Position", "name": "President", "properties": {"title": "President", "level": "", "responsibilities": ""}},
#         "relationship": "HOLDS_TITLE",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   1%|          | 17/1453 [00:24<39:02,  1.63s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:54:12 - INFO
# LLM Response:
# []
#
#   1%|          | 18/1453 [00:25<31:24,  1.31s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:54:14 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Person", "name": "Renato Carlos H. Ermita, Jr.", "properties": {"occupation": "Approver", "rank": "Senior"}},
#         "node_2": {"label": "Miscellaneous", "name": "manual approval and distribution list", "properties": {}},
#         "relationship": "APPROVED",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   1%|▏         | 19/1453 [00:27<36:48,  1.54s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:54:15 - INFO
# LLM Response:
# []
#
#   1%|▏         | 20/1453 [00:27<30:02,  1.26s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:54:16 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Quality Management Office", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "Distribution List", "properties": {}},
#         "relationship": "INCLUDES",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   1%|▏         | 21/1453 [00:29<33:42,  1.41s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:54:18 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Quality Management Office", "properties": {}},
#         "node_2": {"label": "Object", "name": "original copy", "properties": {}},
#         "relationship": "RECEIVED",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   2%|▏         | 22/1453 [00:31<35:46,  1.50s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:54:20 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Organization", "name": "Office of the President", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "distribution list", "properties": {}},
#         "relationship": "INCLUDES",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   2%|▏         | 23/1453 [00:33<36:45,  1.54s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:54:21 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Organization", "name": "Office of the President", "properties": {}},
#         "node_2": {"label": "Object", "name": "copy 1", "properties": {}},
#         "relationship": "RECEIVED",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   2%|▏         | 24/1453 [00:34<36:34,  1.54s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:54:23 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Organization", "name": "Office of the Vice-President for Research and Development", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "distribution list", "properties": {}},
#         "relationship": "INCLUDES",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   2%|▏         | 25/1453 [00:36<38:29,  1.62s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:54:25 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Organization", "name": "Office of the Vice-President for Research and Development", "properties": {}},
#         "node_2": {"label": "Object", "name": "copy 2", "properties": {}},
#         "relationship": "RECEIVED",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   2%|▏         | 26/1453 [00:38<38:30,  1.62s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:54:26 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "distribution list", "properties": {}},
#         "node_2": {"label": "Organization", "name": "Center for Research", "properties": {}},
#         "relationship": "INCLUDES",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   2%|▏         | 27/1453 [00:39<38:07,  1.60s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:54:28 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Organization", "name": "Center for Research", "properties": {}},
#         "node_2": {"label": "Object", "name": "copy 3", "properties": {}},
#         "relationship": "RECEIVED",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   2%|▏         | 28/1453 [00:41<39:54,  1.68s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:54:31 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "distribution list", "properties": {}},
#         "node_2": {"label": "Organization", "name": "Center for Innovation and Entrepreneurship", "properties": {}},
#         "relationship": "INCLUDES",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   2%|▏         | 29/1453 [00:43<45:09,  1.90s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:54:32 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Organization", "name": "Center for Innovation and Entrepreneurship", "properties": {}},
#         "node_2": {"label": "Object", "name": "copy 4", "properties": {}},
#         "relationship": "RECEIVED",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   2%|▏         | 30/1453 [00:45<44:02,  1.86s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:54:34 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Center for Resilient Philippines", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "Distribution List", "properties": {}},
#         "relationship": "INCLUDES",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   2%|▏         | 31/1453 [00:47<43:04,  1.82s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:54:36 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Organization", "name": "Center for Resilient Philippines", "properties": {}},
#         "node_2": {"label": "Object", "name": "copy 5", "properties": {}},
#         "relationship": "RECEIVED",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   2%|▏         | 32/1453 [00:48<41:22,  1.75s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:54:38 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "distribution list", "properties": {}},
#         "node_2": {"label": "Campus", "name": "all campuses", "properties": {}},
#         "relationship": "INCLUDES",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   2%|▏         | 33/1453 [00:50<42:07,  1.78s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:54:39 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Object", "name": "copy 6", "properties": {}},
#         "node_2": {"label": "Campus", "name": "All campuses", "properties": {}},
#         "relationship": "RECEIVED",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   2%|▏         | 34/1453 [00:52<40:06,  1.70s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:54:40 - INFO
# LLM Response:
# []
#
#   2%|▏         | 35/1453 [00:52<31:53,  1.35s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:54:41 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Object", "name": "Manual Version Control Log", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "Table of Contents", "properties": {}},
#         "relationship": "INCLUDES",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   2%|▏         | 36/1453 [00:54<34:15,  1.45s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:54:43 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Manual Approval", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "Distribution List", "properties": {}},
#         "relationship": "INCLUDES",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   3%|▎         | 37/1453 [00:56<35:36,  1.51s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:54:43 - INFO
# LLM Response:
# []
#
#   3%|▎         | 38/1453 [00:56<28:50,  1.22s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:54:44 - INFO
# LLM Response:
# []
#
#   3%|▎         | 39/1453 [00:57<24:08,  1.02s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:54:46 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Object", "name": "Chapter 1: Research and Development", "properties": {}},
#         "node_2": {"label": "Organization", "name": "National University", "properties": {}},
#         "relationship": "IS_PART_OF",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   3%|▎         | 40/1453 [00:59<28:59,  1.23s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:54:47 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Chapter 1", "properties": {}},
#         "node_2": {"label": "Organization", "name": "Center for Research", "properties": {}},
#         "relationship": "INCLUDES",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   3%|▎         | 41/1453 [01:00<31:07,  1.32s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:54:49 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Chapter 1", "properties": {}},
#         "node_2": {"label": "Organization", "name": "B. Center for Innovation and Entrepreneurship", "properties": {}},
#         "relationship": "INCLUDES",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   3%|▎         | 42/1453 [01:02<37:17,  1.59s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:54:51 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Chapter 1", "properties": {}},
#         "node_2": {"label": "Organization", "name": "Center for Resilient Philippines", "properties": {}},
#         "relationship": "INCLUDES",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   3%|▎         | 43/1453 [01:04<35:58,  1.53s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:54:53 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Object", "name": "Table of Contents", "properties": {}},
#         "node_2": {"label": "Chapter", "name": "Chapter 2: National University Research Agenda", "properties": {}},
#         "relationship": "INCLUDES",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   3%|▎         | 44/1453 [01:06<39:06,  1.67s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:54:54 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Chapter 2", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "Research Goals", "properties": {}},
#         "relationship": "INCLUDES",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   3%|▎         | 45/1453 [01:07<36:59,  1.58s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:54:56 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Chapter 2", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "Research Themes", "properties": {}},
#         "relationship": "INCLUDES",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   3%|▎         | 46/1453 [01:09<36:24,  1.55s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:54:57 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Chapter 2", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "C. Research Disciplines", "properties": {}},
#         "relationship": "INCLUDES",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   3%|▎         | 47/1453 [01:10<37:05,  1.58s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:54:59 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "College", "name": "College", "properties": {}},
#         "node_2": {"label": "Campus", "name": "Campus", "properties": {}},
#         "relationship": "INCLUDES",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   3%|▎         | 48/1453 [01:12<37:30,  1.60s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:55:01 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "College", "name": "A. College of Education, Arts and Sciences", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "Chapter 3", "properties": {}},
#         "relationship": "INCLUDES",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   3%|▎         | 49/1453 [01:14<38:46,  1.66s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:55:02 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "College", "name": "B. College of Business and Accountancy", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "Chapter 3", "properties": {}},
#         "relationship": "INCLUDES",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   3%|▎         | 50/1453 [01:15<37:40,  1.61s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:55:04 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Chapter 3", "properties": {}},
#         "node_2": {"label": "College", "name": "College of Architecture", "properties": {}},
#         "relationship": "INCLUDES",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   4%|▎         | 51/1453 [01:17<37:06,  1.59s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:55:05 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Chapter 3", "properties": {}},
#         "node_2": {"label": "College", "name": "D. College of Engineering", "properties": {}},
#         "relationship": "INCLUDES",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   4%|▎         | 52/1453 [01:18<36:53,  1.58s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:55:07 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "College", "name": "E. College of Computing and Information Technologies", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "Chapter 3", "properties": {}},
#         "relationship": "INCLUDES",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   4%|▎         | 53/1453 [01:20<36:46,  1.58s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:55:09 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "College", "name": "F. College of Allied Health", "properties": {}},
#         "node_2": {"label": "Event", "name": "Chapter 3", "properties": {}},
#         "relationship": "INCLUDES",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   4%|▎         | 54/1453 [01:21<37:41,  1.62s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:55:10 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Chapter 3", "properties": {}},
#         "node_2": {"label": "College", "name": "G. College of Dentistry", "properties": {}},
#         "relationship": "INCLUDES",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   4%|▍         | 55/1453 [01:23<35:40,  1.53s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:55:12 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "College", "name": "H. College of Tourism and Hospitality Management", "properties": {"dean": "", "established": "", "programs": ""}},
#         "node_2": {"label": "Miscellaneous", "name": "Chapter 3", "properties": {}},
#         "relationship": "INCLUDES",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   4%|▍         | 56/1453 [01:25<37:32,  1.61s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:55:13 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Chapter 3", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "NU MOA", "properties": {}},
#         "relationship": "INCLUDES",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   4%|▍         | 57/1453 [01:26<37:52,  1.63s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:55:15 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Chapter 3", "properties": {}},
#         "node_2": {"label": "Organization", "name": "J. NU Philippines", "properties": {}},
#         "relationship": "INCLUDES",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   4%|▍         | 58/1453 [01:28<37:36,  1.62s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:55:17 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "University Research and Development Council", "properties": {}},
#         "node_2": {"label": "Event", "name": "Chapter 4", "properties": {}},
#         "relationship": "INCLUDES",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   4%|▍         | 59/1453 [01:29<36:19,  1.56s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:55:18 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Research As Defined By The College Faculty Ranking And Classification System", "properties": {}},
#         "node_2": {"label": "College", "name": "College Faculty", "properties": {}},
#         "relationship": "INCLUDES",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   4%|▍         | 60/1453 [01:31<37:04,  1.60s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:55:20 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Chapter 6: Types of Research Projects", "properties": {}},
#         "node_2": {"label": "Object", "name": "Table of Contents", "properties": {}},
#         "relationship": "INCLUDES",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   4%|▍         | 61/1453 [01:33<37:15,  1.61s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:55:20 - INFO
# LLM Response:
# []
#
#   4%|▍         | 62/1453 [01:33<30:21,  1.31s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:55:22 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Commissioned Research Projects", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "research", "properties": {}},
#         "relationship": "IS_A_TYPE_OF",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   4%|▍         | 63/1453 [01:35<31:45,  1.37s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:55:24 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Specially Funded Research Projects", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "research", "properties": {}},
#         "relationship": "IS_A_TYPE_OF",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   4%|▍         | 64/1453 [01:36<34:11,  1.48s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:55:25 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Internally Funded Research Projects", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "research", "properties": {}},
#         "relationship": "IS_A_TYPE_OF",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   4%|▍         | 65/1453 [01:38<34:43,  1.50s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:55:28 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Externally Funded Research Projects", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "research", "properties": {}},
#         "relationship": "IS_A_TYPE_OF",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   5%|▍         | 66/1453 [01:40<41:10,  1.78s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:55:29 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Professorial Chairs", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "research", "properties": {}},
#         "relationship": "IS_A_TYPE_OF",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   5%|▍         | 67/1453 [01:42<41:03,  1.78s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:55:31 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Publication", "name": "Criteria and Incentives", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "research", "properties": {}},
#         "relationship": "related_to",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   5%|▍         | 68/1453 [01:44<40:12,  1.74s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:55:33 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Journal of Sciences, Technology, And Arts (JSTAR)", "properties": {}},
#         "node_2": {"label": "Event", "name": "Chapter 7", "properties": {}},
#         "relationship": "IS_TITLED",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   5%|▍         | 69/1453 [01:46<43:43,  1.90s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:55:35 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Research Policies", "properties": {}},
#         "node_2": {"label": "Event", "name": "Chapter 8", "properties": {}},
#         "relationship": "IS_TITLED",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   5%|▍         | 70/1453 [01:48<42:49,  1.86s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:55:37 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Policy", "name": "General Research Policy", "properties": {}},
#         "node_2": {"label": "Policy", "name": "Research Policies", "properties": {}},
#         "relationship": "IS_A_SECTION_OF",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   5%|▍         | 71/1453 [01:50<41:24,  1.80s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:55:38 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Research Grants", "properties": {}},
#         "node_2": {"label": "Policy", "name": "Research Policies", "properties": {}},
#         "relationship": "IS_A_SECTION_OF",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   5%|▍         | 72/1453 [01:51<39:51,  1.73s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:55:40 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Research Outputs", "properties": {}},
#         "node_2": {"label": "Policy", "name": "Research Policies", "properties": {}},
#         "relationship": "IS_A_PART_OF",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   5%|▌         | 73/1453 [01:53<38:59,  1.70s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:55:43 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Contractual Obligations of Researchers", "properties": {}},
#         "node_2": {"label": "Organization", "name": "National University", "properties": {}},
#         "relationship": "IS_PART_OF",
#         "metadata": {},
#         "order": null
#     },
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Contractual Obligations of Researchers", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "Research Policies", "properties": {}},
#         "relationship": "IS_A_SECTION_OF",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   5%|▌         | 74/1453 [01:56<47:43,  2.08s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:55:45 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Intellectual Property Policy", "properties": {}},
#         "node_2": {"label": "Event", "name": "Chapter 9", "properties": {}},
#         "relationship": "IS_TITLED",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   5%|▌         | 75/1453 [01:57<44:50,  1.95s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:55:47 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Purpose", "properties": {}},
#         "node_2": {"label": "Policy", "name": "Intellectual Property Policy", "properties": {"type": "Intellectual Property", "effective_date": "", "scope": ""}},
#         "relationship": "IS_A_SECTION_WITHIN",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   5%|▌         | 76/1453 [01:59<44:35,  1.94s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:55:49 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Policy", "name": "Intellectual Property Policy", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "Coverage of Policy Provision", "properties": {}},
#         "relationship": "INCLUDES",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   5%|▌         | 77/1453 [02:01<45:56,  2.00s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:55:50 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Definition of Terms", "properties": {}},
#         "node_2": {"label": "Policy", "name": "Intellectual Property Policy", "properties": {"type": "Intellectual Property", "effective_date": "", "scope": ""}},
#         "relationship": "IS_A_PART_OF",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   5%|▌         | 78/1453 [02:03<43:57,  1.92s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:55:53 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Disclosure Requisites", "properties": {}},
#         "node_2": {"label": "Policy", "name": "Intellectual Property Policy", "properties": {"type": "Intellectual Property", "effective_date": "", "scope": ""}},
#         "relationship": "IS_PART_OF",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   5%|▌         | 79/1453 [02:06<47:48,  2.09s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:55:56 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Policy", "name": "Intellectual Property Policy", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "Administration of the Policy", "properties": {}},
#         "relationship": "HAS_SECTION",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   6%|▌         | 80/1453 [02:08<52:45,  2.31s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:55:58 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Ownership of Trademarks", "properties": {}},
#         "node_2": {"label": "Policy", "name": "Intellectual Property Policy", "properties": {}},
#         "relationship": "IS_A_SECTION_WITHIN",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   6%|▌         | 81/1453 [02:11<51:41,  2.26s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:56:00 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Ownership of Copyright", "properties": {}},
#         "node_2": {"label": "Policy", "name": "Intellectual Property Policy", "properties": {}},
#         "relationship": "IS_A_SECTION_WITHIN",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   6%|▌         | 82/1453 [02:13<49:28,  2.17s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:56:02 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Ownership of Patent", "properties": {}},
#         "node_2": {"label": "Policy", "name": "Intellectual Property Policy", "properties": {"type": "Intellectual Property", "effective_date": "", "scope": ""}},
#         "relationship": "IS_A_SECTION_WITHIN",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   6%|▌         | 83/1453 [02:14<47:39,  2.09s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:56:04 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Distribution of Income from Intellectual Property", "properties": {}},
#         "node_2": {"label": "Policy", "name": "Intellectual Property Policy", "properties": {"type": "Intellectual Property", "effective_date": "", "scope": ""}},
#         "relationship": "IS_PART_OF",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   6%|▌         | 84/1453 [02:16<46:36,  2.04s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:56:06 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Resolution of Disputes", "properties": {}},
#         "node_2": {"label": "Policy", "name": "Intellectual Property Policy", "properties": {"type": "Intellectual Property", "effective_date": "", "scope": ""}},
#         "relationship": "IS_PART_OF",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   6%|▌         | 85/1453 [02:18<45:42,  2.00s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:56:07 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Penalties", "properties": {}},
#         "node_2": {"label": "Policy", "name": "Intellectual Property Policy", "properties": {}},
#         "relationship": "IS_PART_OF",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   6%|▌         | 86/1453 [02:20<42:28,  1.86s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:56:09 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Amendments", "properties": {}},
#         "node_2": {"label": "Policy", "name": "Intellectual Property Policy", "properties": {"type": "Intellectual Property", "effective_date": "", "scope": ""}},
#         "relationship": "IS_PART_OF",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   6%|▌         | 87/1453 [02:22<42:32,  1.87s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:56:11 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Policy", "name": "Waiving of Intellectual Property Policy", "properties": {}},
#         "node_2": {"label": "Policy", "name": "Intellectual Property Policy", "properties": {}},
#         "relationship": "IS_A_SECTION_OF",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   6%|▌         | 88/1453 [02:23<40:47,  1.79s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:56:13 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Repealing Clause", "properties": {}},
#         "node_2": {"label": "Policy", "name": "Intellectual Property Policy", "properties": {"type": "Intellectual Property", "effective_date": "", "scope": ""}},
#         "relationship": "IS_PART_OF",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   6%|▌         | 89/1453 [02:25<41:50,  1.84s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:56:14 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Policy", "name": "Authorship Policy", "properties": {"type": "Authorship", "effective_date": "", "scope": ""}},
#         "node_2": {"label": "Miscellaneous", "name": "Chapter 10", "properties": {}},
#         "relationship": "DESCRIBES",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   6%|▌         | 90/1453 [02:27<41:52,  1.84s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:56:16 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Purpose", "properties": {}},
#         "node_2": {"label": "Policy", "name": "Authorship Policy", "properties": {}},
#         "relationship": "IS_A_SECTION_WITHIN",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   6%|▋         | 91/1453 [02:29<41:15,  1.82s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:56:18 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Policy", "name": "Authorship Policy", "properties": {}},
#         "node_2": {"label": "Policy", "name": "Coverage of Policy Provision", "properties": {}},
#         "relationship": "INCLUDES",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   6%|▋         | 92/1453 [02:31<40:23,  1.78s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:56:20 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Definition of Terms", "properties": {}},
#         "node_2": {"label": "Policy", "name": "Authorship Policy", "properties": {}},
#         "relationship": "IS_A_PART_OF",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   6%|▋         | 93/1453 [02:32<39:51,  1.76s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:56:21 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Guidelines", "properties": {}},
#         "node_2": {"label": "Policy", "name": "Authorship Policy", "properties": {"type": "Authorship", "effective_date": "", "scope": ""}},
#         "relationship": "IS_A_SECTION_WITHIN",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   6%|▋         | 94/1453 [02:34<41:03,  1.81s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:56:23 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Publication", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "Dissemination of Research", "properties": {}},
#         "relationship": "IS_PART_OF",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   7%|▋         | 95/1453 [02:36<39:35,  1.75s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:56:25 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Annual Research Report", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "F.", "properties": {}},
#         "relationship": "RELATED_TO",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   7%|▋         | 96/1453 [02:37<37:43,  1.67s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:56:26 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Research Recognition", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "G.", "properties": {}},
#         "relationship": "IS_PART_OF",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   7%|▋         | 97/1453 [02:39<35:42,  1.58s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:56:27 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Organization", "name": "National University", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "General Ethical Guidelines", "properties": {}},
#         "relationship": "HAS_GUIDELINE",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   7%|▋         | 98/1453 [02:40<35:19,  1.56s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:56:30 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Committee", "name": "University Ethics Review Committee", "properties": {"purpose": "Review ethical implications of research", "members": "Faculty and student representatives", "term_length": "Annual"}},
#         "node_2": {"label": "Miscellaneous", "name": "University", "properties": {}},
#         "relationship": "PART_OF",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   7%|▋         | 99/1453 [02:43<43:18,  1.92s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:56:32 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Policy", "name": "Policy on Ethics", "properties": {"type": "Ethics", "effective_date": "", "scope": ""}},
#         "node_2": {"label": "Miscellaneous", "name": "Ethics", "properties": {}},
#         "relationship": "COVERS",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   7%|▋         | 100/1453 [02:45<42:29,  1.88s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:56:34 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Research Misconduct", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "C.", "properties": {}},
#         "relationship": "IS_A_PART_OF",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   7%|▋         | 101/1453 [02:46<41:18,  1.83s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:56:34 - INFO
# LLM Response:
# []
#
#   7%|▋         | 102/1453 [02:47<32:08,  1.43s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:56:36 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Organization", "name": "National University", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "Welcome", "properties": {}},
#         "relationship": "GREETING",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   7%|▋         | 103/1453 [02:49<32:46,  1.46s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:56:37 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Organization", "name": "National University", "properties": {}},
#         "node_2": {"label": "Object", "name": "Manual", "properties": {}},
#         "relationship": "HAS_PREPARED",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   7%|▋         | 104/1453 [02:50<32:38,  1.45s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:56:39 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Organization", "name": "National University", "properties": {}},
#         "node_2": {"label": "Policy", "name": "Manual", "properties": {"type": "overview", "effective_date": "", "scope": "conduct of research"}},
#         "relationship": "DESCRIBES",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   7%|▋         | 105/1453 [02:52<33:42,  1.50s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:56:41 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Manual", "properties": {}},
#         "node_2": {"label": "Organization", "name": "National University", "properties": {}},
#         "relationship": "INFORMS",
#         "metadata": {},
#         "order": null
#     },
#     {
#         "node_1": {"label": "Organization", "name": "National University", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "Research and Innovation", "properties": {}},
#         "relationship": "HAS_FOCUS_AREA",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   7%|▋         | 106/1453 [02:54<41:14,  1.84s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:56:45 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Object", "name": "The Manual", "properties": {}},
#         "node_2": {"label": "Place", "name": "NU Manila", "properties": {}},
#         "relationship": "PROVIDES_GUIDELINES_FOR",
#         "metadata": {},
#         "order": null
#     },
#     {
#         "node_1": {"label": "Object", "name": "The Manual", "properties": {}},
#         "node_2": {"label": "Place", "name": "NU campuses", "properties": {}},
#         "relationship": "PROVIDES_GUIDELINES_FOR",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   7%|▋         | 107/1453 [02:57<49:49,  2.22s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:56:49 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Organization", "name": "NU Manila", "properties": {}},
#         "node_2": {"label": "Organization", "name": "NU Philippines", "properties": {}},
#         "relationship": "IS_PART_OF",
#         "metadata": {},
#         "order": null
#     },
#     {
#         "node_1": {"label": "Organization", "name": "NU campuses", "properties": {}},
#         "node_2": {"label": "Organization", "name": "NU Philippines", "properties": {}},
#         "relationship": "IS_PART_OF",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   7%|▋         | 108/1453 [03:02<1:05:34,  2.93s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:56:50 - INFO
# LLM Response:
# []
#
#   8%|▊         | 109/1453 [03:02<49:28,  2.21s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:56:52 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Object", "name": "The Manual", "properties": {}},
#         "node_2": {"label": "Organization", "name": "National University", "properties": {}},
#         "relationship": "GOVERNS",
#         "metadata": {},
#         "order": null
#     },
#     {
#         "node_1": {"label": "Organization", "name": "National University", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "Research agenda and contracts", "properties": {}},
#         "relationship": "MONITORS",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   8%|▊         | 110/1453 [03:05<52:12,  2.33s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:56:53 - INFO
# LLM Response:
# []
#
#   8%|▊         | 111/1453 [03:06<40:27,  1.81s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:56:53 - INFO
# LLM Response:
# []
#
#   8%|▊         | 112/1453 [03:06<32:05,  1.44s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:56:55 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Place", "name": "campus", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "situation", "properties": {}},
#         "relationship": "HAS_POTENTIAL",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#   8%|▊         | 113/1453 [03:08<36:20,  1.63s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:56:56 - INFO
# LLM Response:
# []
#
#   8%|▊         | 114/1453 [03:09<30:04,  1.35s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 21:57:00 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Manual", "properties": {}},
# ...
#         "node_2": {"label": "Event", "name": "Research Undertaking", "properties": {"type": "Research", "context": "Specific research activities"}},
#         "relationship": "POTENTIAL_CONFLICT",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#  97%|█████████▋| 1403/1453 [54:03<02:31,  3.04s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:47:51 - INFO
# LLM Response:
# []
#
#  97%|█████████▋| 1404/1453 [54:04<01:54,  2.33s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:47:54 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Organization", "name": "Northwestern University", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "research misconduct", "properties": {}},
#         "relationship": "considers",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#  97%|█████████▋| 1405/1453 [54:07<02:00,  2.51s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:47:55 - INFO
# LLM Response:
# []
#
#  97%|█████████▋| 1406/1453 [54:07<01:30,  1.92s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:47:55 - INFO
# LLM Response:
# []
#
#  97%|█████████▋| 1407/1453 [54:08<01:11,  1.56s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:47:56 - INFO
# LLM Response:
# []
#
#  97%|█████████▋| 1408/1453 [54:09<00:59,  1.33s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:47:57 - INFO
# LLM Response:
# []
#
#  97%|█████████▋| 1409/1453 [54:10<00:49,  1.12s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:48:00 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Falsification of research", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "deliberately misrepresenting research", "properties": {}},
#         "relationship": "involves",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#  97%|█████████▋| 1410/1453 [54:12<01:08,  1.60s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:48:02 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Falsification of research", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "misrepresenting the progress of research", "properties": {}},
#         "relationship": "INCLUDES",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#  97%|█████████▋| 1411/1453 [54:14<01:12,  1.72s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:48:06 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Falsification of research", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "Exaggerated claims", "properties": {}},
#         "relationship": "INCLUDES",
#         "metadata": {},
#         "order": null
#     },
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Exaggerated claims", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "Significance of research results", "properties": {}},
#         "relationship": "RELATES_TO",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#  97%|█████████▋| 1412/1453 [54:18<01:38,  2.40s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:48:06 - INFO
# LLM Response:
# []
#
#  97%|█████████▋| 1413/1453 [54:19<01:17,  1.93s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:48:07 - INFO
# LLM Response:
# []
#
#  97%|█████████▋| 1414/1453 [54:20<00:58,  1.51s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:48:08 - INFO
# LLM Response:
# []
#
#  97%|█████████▋| 1415/1453 [54:21<00:52,  1.39s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:48:09 - INFO
# LLM Response:
# []
#
#  97%|█████████▋| 1416/1453 [54:21<00:42,  1.15s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:48:09 - INFO
# LLM Response:
# []
#
#  98%|█████████▊| 1417/1453 [54:22<00:34,  1.04it/s]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:48:10 - INFO
# LLM Response:
# []
#
#  98%|█████████▊| 1418/1453 [54:23<00:32,  1.07it/s]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:48:11 - INFO
# LLM Response:
# []
#
#  98%|█████████▊| 1419/1453 [54:23<00:27,  1.22it/s]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:48:11 - INFO
# LLM Response:
# []
#
#  98%|█████████▊| 1420/1453 [54:24<00:23,  1.38it/s]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:48:13 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Abuse of confidentiality", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "ideas and data", "properties": {}},
#         "relationship": "involves",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#  98%|█████████▊| 1421/1453 [54:26<00:35,  1.10s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:48:14 - INFO
# LLM Response:
# []
#
#  98%|█████████▊| 1422/1453 [54:26<00:28,  1.08it/s]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:48:18 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Abuse of confidentiality", "properties": {}},
#         "node_2": {"label": "Object", "name": "grant proposals", "properties": {}},
#         "relationship": "INCLUDES",
#         "metadata": {},
#         "order": null
#     },
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Abuse of confidentiality", "properties": {}},
#         "node_2": {"label": "Object", "name": "award applications", "properties": {}},
#         "relationship": "INCLUDES",
#         "metadata": {},
#         "order": null
#     },
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Abuse of confidentiality", "properties": {}},
#         "node_2": {"label": "Object", "name": "manuscript publication", "properties": {}},
#         "relationship": "INCLUDES",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#  98%|█████████▊| 1423/1453 [54:31<01:03,  2.11s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:48:20 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Dishonesty in publication", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "misleading material", "properties": {}},
#         "relationship": "involves",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#  98%|█████████▊| 1424/1453 [54:33<00:59,  2.03s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:48:24 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Dishonesty in publication", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "misrepresenting data", "properties": {}},
#         "relationship": "includes",
#         "metadata": {},
#         "order": null
#     },
#     {
#         "node_1": {"label": "Miscellaneous", "name": "misrepresenting data", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "originality", "properties": {}},
#         "relationship": "particularly",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#  98%|█████████▊| 1425/1453 [54:37<01:09,  2.48s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:48:26 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Dishonesty in publication", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "misrepresenting research progress", "properties": {}},
#         "relationship": "INCLUDES",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#  98%|█████████▊| 1426/1453 [54:38<01:01,  2.28s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:48:28 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Dishonesty in publication", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "Adding names of authors without permission", "properties": {}},
#         "relationship": "INCLUDES",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#  98%|█████████▊| 1427/1453 [54:40<00:57,  2.20s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:48:31 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Dishonesty in publication", "properties": {}},
#         "node_2": {"label": "Object", "name": "honorary authorships", "properties": {}},
#         "relationship": "INCLUDES",
#         "metadata": {},
#         "order": null
#     },
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Dishonesty in publication", "properties": {}},
#         "node_2": {"label": "Object", "name": "major collaborator", "properties": {}},
#         "relationship": "EXCLUDES",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#  98%|█████████▊| 1428/1453 [54:44<01:05,  2.61s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:48:35 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Misuse of funds", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "research funds", "properties": {}},
#         "relationship": "INVOLVES",
#         "metadata": {},
#         "order": null
#     },
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Misuse of funds", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "contract documents", "properties": {}},
#         "relationship": "CONSISTENT_WITH",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#  98%|█████████▊| 1429/1453 [54:48<01:09,  2.91s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:48:35 - INFO
# LLM Response:
# []
#
#  98%|█████████▊| 1430/1453 [54:48<00:50,  2.20s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:48:37 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Mistreatment of human research subjects", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "Failing to inform individuals and communities", "properties": {}},
#         "relationship": "INCLUDES",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#  98%|█████████▊| 1431/1453 [54:50<00:47,  2.16s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:48:42 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Researchers", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "Report", "properties": {}},
#         "relationship": "SUPPLY",
#         "metadata": {},
#         "order": null
#     },
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Report", "properties": {}},
#         "node_2": {"label": "Person", "name": "Individuals", "properties": {}},
#         "relationship": "SUBJECT_OF",
#         "metadata": {},
#         "order": null
#     },
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Report", "properties": {}},
#         "node_2": {"label": "Place", "name": "Community", "properties": {}},
#         "relationship": "SUBJECT_OF",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#  99%|█████████▊| 1432/1453 [54:55<01:01,  2.92s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:48:45 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Researchers", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "Research Subjects", "properties": {}},
#         "relationship": "MISTREAT",
#         "metadata": {},
#         "order": null
#     },
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Researchers", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "Informed Consent", "properties": {}},
#         "relationship": "FAIL_TO_OBTAIN",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#  99%|█████████▊| 1433/1453 [54:58<00:59,  2.96s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:48:46 - INFO
# LLM Response:
# []
#
#  99%|█████████▊| 1434/1453 [54:59<00:42,  2.24s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:48:48 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Research Misconduct", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "Failure to Report", "properties": {}},
#         "relationship": "INCLUDES",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#  99%|█████████▉| 1435/1453 [55:00<00:37,  2.11s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:48:51 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "Retaliation against informants", "properties": {}},
#         "node_2": {"label": "Person", "name": "individual", "properties": {}},
#         "relationship": "INVOLVES",
#         "metadata": {},
#         "order": null
#     },
#     {
#         "node_1": {"label": "Person", "name": "individual", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "major research offenses", "properties": {}},
#         "relationship": "REPORTED_FOR",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#  99%|█████████▉| 1436/1453 [55:03<00:41,  2.42s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:48:53 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "group research project", "properties": {}},
#         "node_2": {"label": "Person", "name": "leaders", "properties": {"occupation": "supervisor"}},
#         "relationship": "HAS_ROLE",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#  99%|█████████▉| 1437/1453 [55:06<00:38,  2.40s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:48:54 - INFO
# LLM Response:
# []
#
#  99%|█████████▉| 1438/1453 [55:06<00:27,  1.84s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:48:54 - INFO
# LLM Response:
# []
#
#  99%|█████████▉| 1439/1453 [55:07<00:20,  1.47s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:48:55 - INFO
# LLM Response:
# []
#
#  99%|█████████▉| 1440/1453 [55:07<00:15,  1.18s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:48:55 - INFO
# LLM Response:
# []
#
#  99%|█████████▉| 1441/1453 [55:08<00:11,  1.01it/s]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:48:56 - INFO
# LLM Response:
# []
#
#  99%|█████████▉| 1442/1453 [55:09<00:09,  1.12it/s]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:48:58 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Position", "name": "Project Leader", "properties": {"responsibilities": "Appointment of suitably qualified research assistants"}},
#         "node_2": {"label": "Person", "name": "Research Assistant", "properties": {}},
#         "relationship": "HAS_ROLE",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#  99%|█████████▉| 1443/1453 [55:11<00:12,  1.27s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:49:01 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Position", "name": "Project Leader", "properties": {"responsibilities": "supervision of research assistants", "title": "Leader", "level": "Senior"}},
#         "node_2": {"label": "Activity", "name": "Research", "properties": {"type": "Research Project", "date": "Ongoing", "participants": "Research Assistants"}},
#         "relationship": "SUPERVISES",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#  99%|█████████▉| 1444/1453 [55:14<00:16,  1.83s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:49:04 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Organization", "name": "OVPRnD", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "online submission and approval of documents", "properties": {}},
#         "relationship": "advocates",
#         "metadata": {},
#         "order": null
#     }
# ]
#
#  99%|█████████▉| 1445/1453 [55:17<00:16,  2.08s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:49:05 - INFO
# LLM Response:
# []
#
# 100%|█████████▉| 1446/1453 [55:17<00:11,  1.66s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:49:05 - INFO
# LLM Response:
# []
#
# 100%|█████████▉| 1447/1453 [55:18<00:07,  1.33s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:49:06 - INFO
# LLM Response:
# []
#
# 100%|█████████▉| 1448/1453 [55:18<00:05,  1.09s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:49:08 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Miscellaneous", "name": "IFRP P processing", "properties": {}},
#         "node_2": {"label": "Miscellaneous", "name": "eSignatures", "properties": {}},
#         "relationship": "INCLUDES",
#         "metadata": {},
#         "order": null
#     }
# ]
#
# 100%|█████████▉| 1449/1453 [55:20<00:05,  1.39s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:49:09 - INFO
# LLM Response:
# []
#
# 100%|█████████▉| 1450/1453 [55:21<00:03,  1.24s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:49:09 - INFO
# LLM Response:
# []
#
#
# 100%|█████████▉| 1451/1453 [55:22<00:02,  1.07s/it]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:49:10 - INFO
# LLM Response:
# []
#
# 100%|█████████▉| 1452/1453 [55:23<00:00,  1.10it/s]
# ▶︎ GRAPH MAKER VERBOSE - 2026-02-20 22:49:10 - INFO
# LLM Response:
# []
#
# 100%|██████████| 1453/1453 [55:23<00:00,  2.29s/it]

# %% [markdown]
# With ER

# %%
# 1. Initialize predicate vocab for relational signatures
# pred2idx = {"works_at":0, "owns":1, "located_in":2}
pred2idx = {}

# 2. Initialize resolver
resolver = ClusterER(pred2idx=pred2idx, sim_threshold=0.65)

unique_edges = resolver.process_edges(list_of_edges)

if createGraph(unique_edges):
    print("Success")
else:
    print("Failed")

# %% [markdown]
# Without ER

# %%
if createGraph(list_of_edges):
    print("Success")
else:
    print("Failed")

# %%
data = [
    {
        "ID": 1,
        "Question": "What is the primary purpose of the National University Research Manual?",
        "Answer": "The Manual provides an overview of National University's policies, processes, and regulations for the conduct of research, aiming to familiarize constituents with important information about Research and Innovation, and provide guidelines for efficient and ethical research within NU Manila and other NU campuses."
    },
    {
        "ID": 2,
        "Question": "What is the reference number of this Research Manual?",
        "Answer": "The reference number of the Research Manual is RAD-RS-D-M-001."
    },
    {
        "ID": 3,
        "Question": "What are the three university-wide research centers established by National University?",
        "Answer": "The three university-wide research centers are the Center for Research, the Center for Innovation and Entrepreneurship, and the Center for Resilient Philippines."
    },
    {
        "ID": 4,
        "Question": "What is the vision of the Center for Entrepreneurship?",
        "Answer": "The Center for Entrepreneurship is envisioned to be an inclusive, realistic, and collaborative community."
    },
    {
        "ID": 5,
        "Question": "What are some of the core competencies identified by the Center for Resilient Philippines (CRP)?",
        "Answer": "The core competencies of the CRP include disaster resilience from social/political, economic, and physical sciences perspectives; new technology-enabled mechanisms for resilient community planning and design; development of innovative national and local resilience policies; private sector engagement in disaster resilience; capacity building for disaster mitigation and reconstruction; networking with the academic community; and community engagement and participation in reconstruction."
    },
    {
        "ID": 6,
        "Question": "Name at least three research goals of the National University Research Agenda.",
        "Answer": "Some research goals include: to recruit, develop, and retain faculty researchers; to provide proactive service to the academic community on research-related endeavors; to assist faculty researchers in publishing outputs in top international journals; to obtain and manage externally funded research projects; and to foster collaboration with local and international higher education institutions."
    },
    {
        "ID": 7,
        "Question": "What are some of the Research Themes outlined in the National University Research Agenda?",
        "Answer": "Research Themes include Food, Nutrition, and Health; Emerging Industries on the Fourth Industrial Revolution; Development of vaccines and diagnostic kits using indigenous materials; Disaster risk management; Tourism and Pollution control; Climate change; Sports Technology; Education and learning innovations; and Business sophistication."
    },
    {
        "ID": 8,
        "Question": "Which colleges or campuses have their research agenda defined in the manual?",
        "Answer": "The manual defines the research agendas for the College of Education, Arts and Sciences (CEAS), College of Business and Accountancy (CBA), College of Architecture (COA), College of Engineering (COE), College of Computing and Information Technologies (CCIT), College of Allied Health (CAH), College of Dentistry (COD), and College of Tourism and Hospitality Management (CTHM)."
    },
    {
        "ID": 9,
        "Question": "What is the Journal of Sciences, Technology, and Arts (JSTAR)?",
        "Answer": "JSTAR is the official, peer-reviewed, open-access publication of National University (Philippines), published annually by the Center for Research, providing a venue for students, faculty, non-teaching personnel, and industry practitioners to share research works, empirical studies, and theories related to science, technology, and arts."
    },
    {
        "ID": 10,
        "Question": "According to the Authorship Policy, what is the minimum total points an individual needs in the co-authorship scoring system to share authorship?",
        "Answer": "Anyone achieving a total of 25 points in the co-authorship scoring system shares authorship."
    },
    {
        "ID": 11,
        "Question": "What is the current budget allocated for the Center for Innovation and Entrepreneurship for the upcoming fiscal year?",
        "Answer": ""
    },
    {
        "ID": 12,
        "Question": "Who is the specific contact person for submitting research proposals for the College of Allied Health, including their email address and phone number?",
        "Answer": ""
    },
    {
        "ID": 13,
        "Question": "What are the detailed procedures and forms required for intellectual property registration for a patent developed by a faculty member?",
        "Answer": ""
    },
    {
        "ID": 14,
        "Question": "How many research projects were successfully published in international journals last year, broken down by college?",
        "Answer": ""
    },
    {
        "ID": 15,
        "Question": "What is the average duration of a research project from proposal submission to final dissemination of results?",
        "Answer": ""
    },
    {
        "ID": 16,
        "Question": "Are there any specific grants or funding opportunities available exclusively for student-led research initiatives?",
        "Answer": ""
    },
    {
        "ID": 17,
        "Question": "What is the protocol for handling research misconduct cases involving external collaborators?",
        "Answer": ""
    },
    {
        "ID": 18,
        "Question": "Which specific software or tools are recommended by the Office of the Vice President for Research and Development for data analysis in research projects?",
        "Answer": ""
    },
    {
        "ID": 19,
        "Question": "What are the benefits or incentives offered to faculty members who successfully obtain external funding for their research?",
        "Answer": ""
    },
    {
        "ID": 20,
        "Question": "When is the next scheduled workshop or training session for new faculty members on research ethics and compliance?",
        "Answer": ""
    }
]
